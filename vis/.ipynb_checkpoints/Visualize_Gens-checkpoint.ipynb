# %%
import pickle
from binding_affinity_predictor import *
from admet_selenium_extraction import automated_admet
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit.Chem import AllChem
from sklearn.metrics import silhouette_score, pairwise_distances
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import squareform
from Chromosome import *
from GeneticMutation import *

# %%
def get_admet(molecules):
    return automated_admet(molecules)

# %%
def get_pareto_ranking(fitness_scores):
    def dominates(sol1, sol2):
        return all(x <= y for x, y in zip(sol1, sol2)) and any(x < y for x, y in zip(sol1, sol2))
    
    num_solutions = len(fitness_scores)
    pareto_levels = np.zeros(num_solutions, dtype=int)  # Initialize ranks

    for i in range(num_solutions):
        for j in range(num_solutions):
            if i != j:
                if dominates(fitness_scores[j], fitness_scores[i]):
                    pareto_levels[i] += 1  # Increase rank if solution i is dominated by solution j

    return pareto_levels

# %%
def get_cluster(molecules):
    # Create similarity matrix
    fpgen = AllChem.GetMorganGenerator()
    molecules_fingerprint = [fpgen.GetFingerprint(Chem.MolFromSmiles(molecule)) for molecule in molecules]

    # Manually calculate the Tanimoto distance matrix
    n = len(molecules_fingerprint)
    dist_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(i + 1, n):
            tanimoto_sim = DataStructs.TanimotoSimilarity(molecules_fingerprint[i], molecules_fingerprint[j])
            dist_matrix[i, j] = 1 - tanimoto_sim
            dist_matrix[j, i] = dist_matrix[i, j]  # Matrix is symmetric

    condensed_dist_matrix = squareform(dist_matrix)
    # Cluster the similarity matrix while identfying optimal number of clusters
    cluster_linkage = linkage(condensed_dist_matrix, method='average')
    max_clusters = min(len(molecules)//2, 50)
    # Calculate silhouette score for each number of clusters
    silhouette_scores = []
    for n_clusters in range(2, max_clusters + 1):
        labels = fcluster(cluster_linkage, n_clusters, criterion='maxclust')
        score = silhouette_score(dist_matrix, labels, metric='precomputed')
        silhouette_scores.append(score)
    # Optimal number of clusters is the one with the maximum silhouette score
    optimal_clusters = np.argmax(silhouette_scores) + 2
    print(f'Optimal number of clusters: {optimal_clusters}')

    # Cluster the molecules
    labels = fcluster(cluster_linkage, optimal_clusters, criterion='maxclust')
    return labels

# %%
def get_scores(population, fitness_scores):
    # (Pareto Ranking, Cluster)
    scores = list(zip(get_pareto_ranking(fitness_scores), get_cluster(population)))
    return scores

# %%
def get_binding_affinity(molecules):
    model_filepath = "./trainer.pkl"
    predicted_affinity = get_binding_affinities(molecules, model_filepath)
    return predicted_affinity

# %%
def get_fitness(molecules):
    # Get Admet and Get SA are merged
    admet_props = get_admet(molecules).values.tolist()

    # Predicted binding affinity (e.g., lower values are better for binding affinity)
    binding_affinity = get_binding_affinity(molecules)
    for i in range(len(admet_props)):
        admet_props[i].append(binding_affinity[i])

    # for i in range(len(admet_props)):
    #     for index in [2, 3, 4, 9, 10, 11, 12]:
    #         admet_props[i][index] = -admet_props[i][index]
    admet_props = [tuple(admet_prop) for admet_prop in admet_props]

    return admet_props

# %%
with open("../history/log.pkl", "rb") as f:
    up = pickle.Unpickler(f)
    history = up.load()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19412\965789556.py in <module>
#       1 with open("../history/log.pkl", "rb") as f:
#       2     up = pickle.Unpickler(f)
# ----> 3     history = up.load()
#
# AttributeError: Can't get attribute 'LoaderCallableStatus' on <module 'sqlalchemy.orm.base' from 'C:\\Users\\tubon\\.conda\\envs\\chemo\\lib\\site-packages\\sqlalchemy\\orm\\base.py'>

# %%
last_population = history[-1]["population_smiles"]

# %%
print(len(list(set(last_population))))
print("\n".join(list(set(last_population))))
# Out:
# 324
# CN(N)Cc1cnc2nc(N)nc(N)c2n1
# N=CNC(=CN)C(O)CN
# CC(O)=CC(C)(O)CCC(NN)C(=O)O
# CN(Nc1cncnc(N)nc(N)cn1)c1cccc(C(=O)NC(CCC(=O)O)C(=O)O)c1
# NC1NC(=S)c2[nH]cnc2N1
# CC(=NC=C(N)NN)N=C(N)N=CN
# C=C1CCC(O)CC(CCN)(C(=O)O)NC(=O)C(C)=CC=C(C)C(S)=N1
# CC(=O)N=CNS
# C=C1CCC(O)CNNC(C(=O)NC(CCC(=O)O)C(=O)O)=CC(C)=CC(S)=N1
# BCNO
# NCCC(N)C(=O)O
# CN(Cc1cnc2nc(N)nc(N)c2n1)c1ccc(C(=N)NO)cc1
# C=C(N)NC(N)NC
# O=S
# N=CNC(NC(=O)c1cccc(CNNc2cnc3nc(N)nc(N)c3n2)c1)C(=O)O
# S=c1nc2[nH]c3nn2cc1N3
# CC(C)(N)O
# NC#CC(=O)O
# NC(O)O
# CCN
# CC(=NC=C(N)CN(N)CC(=O)O)N=C(N)N=CN
# NC(S)=NNC(CCC(=O)O)C(=O)O
# N=c1[nH]c2c(c(=S)[nH]1)NCN2
# C=NC(NC(=C)N)C(=O)O
# Nc1ccn(C2OC(CO)C(O)C2O)c(=O)n1
# C=C(N)N=C(NC)C(=O)O
# CC(C)(O)C=S
# NC1=NC(=S)N(N)C=COC2C(C1)OC(n1ccc(N)nc1=O)C2O
# C=C(NC=N)C(=S)NC(=N)N
# CC
# OCCO
# NCCC(=O)F
# C=NC(=NC(=C)N)NC=N
# C=C(CCC(C)O)N=C(S)C(C)=CC=C(NC=N)C(=O)NC(CCC(=O)O)C(=O)O
# NCCBr
# CC(N)=NCC=CC(C)(O)CCC(NN)C(=O)O
# CC(O)(C=CCN=C(N)I)CCC(N=N)C(=O)O
# CC(C(=O)O)C(NC(=N)c1ccc(N(C)Cc2cnc3nc(N)nc(N)c3n2)cc1)C(=O)O
# C=C(NC=N)C(=S)N=C(N)C(NC(=O)c1ccc(N(C)Cc2cnc3nc(N)nc(N)c3n2)cc1)C(=O)O
# CC(=CC(C)(C)O)NCNS
# NC=CC(=O)Br
# NCO
# NCC(=O)O
# N=CCC(=O)O
# N=c1[nH]c2c(c(=S)[nH]1)N=C=N2
# O=C1CO1
# S=C1NN=CNc2nc[nH]c21
# C=C1C(N)=NC(=O)N1C1OC(OO)CC1=O
# CN
# CC(=O)N=CSN
# NC=CO
# C=C(C)N
# C=C(N=C=N)C(=S)NC(=N)N
# NN(O)C=O
# CC(C)=CC=C(C(N)=O)C(=CC(C)(C)O)NC(N)S
# S=c1nc2[nH]c3nc([nH]c13)N2
# BN
# N=O
# Nc1ccn(C2OC(OC=C(NNC(CCC(=O)O)C(=O)O)C(=O)NC(CCC(=O)O)C(=O)O)CC2=O)c(=O)n1
# NCC(N)C(=O)O
# CC(=CC(C)(O)CCC(N)C(=O)O)N=C(N)S
# C=C(N)C=CC(O)CC(C)(O)C=C(C)N=C(N)S
# CC(=CC(C)(O)CC(CNC(=O)c1cccc(CNNc2cnc3nc(N)nc(N)c3n2)c1)C(=O)O)N=C(N)S
# CC(=O)N=C(N)C=CC(=O)O
# CN(NCCC(=O)O)c1cccc(C(=O)NC(CCC(=O)O)C(=O)O)c1
# C=C(N)C=CC(O)CCN
# C=C(CCl)N=C(N)Cl
# Nc1bcn(C2OC(O)(C=O)CC2=O)c(=O)n1
# CN(Cc1cnc2nc(N)nc(N)c2n1)c1ccc(C(=O)NC(CCC(=O)O)C(=O)O)cc1
# C=C(NC=N)C(=S)NC(N)=C(O)C(CCC(C)(O)C=CCN=C(C)N)NN
# CC(=NC(=CN)NN)N=C(N)N=CN
# C=C(N)C1=CN1
# C=C1C(N)=NC(=O)N1C1(O)C(=O)CC1OO
# CC(=O)N=C(N)Br
# N=Cn1[nH]c2c(c1=S)NCN2
# Nc1ccn(C2OC(CC(=O)O)C(O)C2O)c(=O)n1
# C=C(CCC(C)O)N=C(S)C=C(C)C=C(NNC(CCC(=O)O)C(=O)O)C(=O)NC(CCC(=O)O)C(=O)O
# C=C(NN=C(N)N=C=N)C(=S)NC(N)N
# NN=C(N)S
# S=C1N=CNNc2nc[nH]c21
# NC=CN
# C=C(NC=N)C(=S)N(CN)C(=C)NC=N
# C=NC(=NC(=C)N)SN
# C=C(CCl)N=C(N)S
# CC(O)(C=CCN=C(N)S)C=CC(=O)O
# N
# C=NNN
# C=C(CCC(C)O)N=C(S)C(C)=CC=C(C)C(=O)NC(Cl)C(=O)O
# NC1=NC(=O)N2C1=CC1C(=O)C2(O)C1OC=O
# O=C1C=C=NO1
# CC(=CC(C)(O)CCC(=N)C(=O)O)N=C(N)S
# CC(C=N)=NC=C(N)CN(N)CC(=O)O
# C=C(CCC(C)O)N=O
# NCCC(NN)C(=O)O
# Nc1ccn(C2OC(OCCC(=O)O)CC2=O)c(=O)n1
# NC=NCC=O
# CC(=CC(C)(O)CCC(N)C(=O)O)NC(N)S
# Nc1nc(N)c2nc(NNCc3cccc(C(=O)NC(=O)O)c3)cnc2n1
# CC(=CC(C)(O)C(=O)O)NC(N)S
# C=C(NC=N)C(=S)NC(N)C(=C)NC=N
# C=C(NN)C(=S)N=C(N)CC1OC(n2ccc(N)nc2=O)C(O)C1O
# S=c1ncn2[nH]c3nc2c1[nH]3
# S=c1nc2[nH]c3nc2[nH]c13
# N=CNC=CNN
# CC(=CC=C(C)N(C)CC(N)=CN=C(C)N=C(N)N=CN)C(=O)NC(C(=O)O)C(N)=NC(N)=S
# CN(Cc1cnc2nc(N)nc(N)c2n1)c1ccc(C(=N)NC(CCC(=O)O)C(=O)O)cc1
# CC(=NN=C(N)CN(N)CC(=O)O)N=C(N)N=C=N
# COC(C=O)OC(CO)N(C=O)C=CC(=N)CC(NC(=O)c1cccc(CNNc2cnc3nc(N)nc(N)c3n2)c1)C(=O)O
# C=NC(N)=NC(O)CN
# C=C(CCC(=O)O)N=C(S)C(C)=CC=C(C)C(=O)NC(CCC(=O)O)C(=O)O
# CC(O)O
# C=C1CCC(O)CC(CCC(=O)O)(C(=O)O)NC(=O)C(C)=CC=C(C)C(S)=N1
# C=C(N)C=CN
# NN(O)O
# CC(CN)C(O)=C(NC(O)(C=O)C(C)OC=O)C(N)=NC=O
# NC=CC(=S)OCN
# C=C(N)NC(N)NN
# C=NC(N)=NC(=C)C(C)(C)O
# CN(N)CC1CN=c2nc(N)nc(N)c2=N1
# CC(=CC=CCC(=O)NC(NC=N)C(O)O)CNNC(C=N)=NC(C)=C(N)N=C(N)C(C)CCC(C)O
# Nc1ccn(C2OC(C=O)C(O)C2O)c(=O)n1
# NCCC(=O)O
# CC(=CC(C)(O)CCC(O)NC(=O)c1cccc(CNNc2cnc3nc(N)nc(N)c3n2)c1)N=C(N)S
# CC(O)(C=CCN=C(N)S)CCC(NN)C(=O)O
# NNC=CC1(O)CC(O)C(n2ccc(N)nc2=O)O1
# CC(=O)N=C(Cl)Br
# C=C(CCC(C)O)N=C(C)NNCC(C)=CC=CCC(=O)NC(CCC(C)(O)C=C(C)N=C(N)S)C(=O)O
# CC(CN)C(=O)O
# C=O
# N=CS
# NO
# C=C(NC=N)C(=S)N=C(N)C(C)(O)C=C(C)N=C(N)S
# CC(=CC=C(NN)C(=O)NC(CCC(=O)O)C(=O)O)C(S)=NN
# CC(N)=NCC=CC(C)(O)PCC(NN)C(=O)O
# Nc1nc(N)c2nc(NNCc3cccc(C(=O)NC(CCC(=O)F)C(=O)O)c3)cnc2n1
# C=NC(N)=NC(=C)N
# CC(=CC=C(Cl)CCCC(=O)O)CN
# CC1(O)C=C(N=C(N)S)CC1
# CC(=NC=C(N)CN(N)CCN)N=C(N)N=CN
# CC(N)C(=O)O
# CC(=CC=C(Cl)CCl)CN
# NCCC(=O)C(=O)O
# NCN
# B=O
# O=c1cc[nH]o1
# C=C(CCC(C)O)N=C(N)S
# C=C(O)CN
# Nc1nc(=O)n2cc1N(C(CCC(=O)O)C(=O)O)C(=O)C(NNC(CCC(=O)O)C(=O)O)=COC1CC(=O)C2O1
# N=CNN
# N=Cn1[nH]c2nc[nH]c2c1=S
# CC(=CC=C(C)N(C)CC(N)=CP=C(C)N=C(N)N=CN)C(=O)CC1OC(n2ccc(N)nc2=O)C(O)C1O
# C=NC(N)NC(=C)N
# N=c1nc(N)[nH]c2nc[nH]c12
# C=C(CCC(C)O)N=C(S)C(C)=CC=C(C)C(=O)NC(CCC(=O)O)C(=O)O
# NC=O
# Cc1c(=S)ncn2[nH]cnc12
# C=C(CCC(C)O)N=C(S)C(C)=CC=C(NN)C(=O)NC(CCO)C(=O)O
# CC(=CC(C)(O)CCC(N)C(O)O)NC(N)S
# C=C(CC=C(C)O)N=C(S)C(C)=CC=C(NN)C(=O)NC(CCC(=O)O)C(=O)O
# NC(=O)C1=CC(CNNc2cnc3nc(N)nc(N)c3n2)CC=C1
# CC(=NC=C(N)CN(N)CC(=O)O)N=C(N)N=C=N
# C=C(N)C(=S)N=C(N)CC1OC(n2ccc(N)nc2=O)C(O)C1O
# CC(=O)N=C(N)S
# CCCC=C(C)SC(=CC(N)=O)NCC(NC(=O)c1cccc(CNNc2cnc3nc(N)nc(N)c3n2)c1)C(=O)O
# CNC1(N)C=C(N)N1
# N=C=CC(=O)O
# Nc1nc(N)c2nc(NNCc3cccc(C(=O)NC(CCC(=O)O)C(=O)O)c3)cnc2n1
# C=C(NC=N)C(=S)N=C(N)CCC1(O)OC(n2ccc(N)nc2=O)C1O
# C=CC(N)=CN
# C=C(CCC(C)O)N=C(S)C(C)=CC=C(NN)C(=O)NC(CCC(=O)O)C(=O)O
# C=NNC=NC(=C)N
# C=C(NC=N)C(=S)NC(N)N
# N=C1NCN=CNCC(=S)N1
# Nc1nc(N)c2nc(CCNc3ccc(C(=O)NC(CCC(=O)O)C(=O)O)cc3)cnc2n1
# C=C(NC=N)C(=S)NC(N)=C(O)C(N)CCC(C)(O)CC(C)NC(N)S
# C=NC(N)=C(C)N=CNCN=CN
# NC=C(O)CO
# CC=N
# C=C(CCCOC)N=C(N)S
# C=C(NC=N)C(=S)NC(N)C(=C)O
# NCCCOO
# NC=CC(=O)O
# CC(O)(C=O)OC(C=O)N(C=O)C=CC(=N)CCN
# CC(=NC(N)=CCN(N)CCN)N=C(N)N=C=N
# CC(=NCC(N)N)N=C(N)N=CN
# NCCC(O)C(=O)O
# Nc1ccn(C2OC(C=O)C3OC32O)c(=O)n1
# NCOC(=S)CO
# C=c1[nH]cnn(C=N)c(=C)n(CN)c1=S
# Nc1c#cn(C2OC(OC=O)CC2=O)c(=O)n1
# CC(=CC(C)(C)O)NC(N)S
# CC(O)CN
# NNC1COC2C(CC(N)=NC1=S)OC(n1ccc(N)nc1=O)C2O
# N=C(N)C=CN(C=O)C(CO)OC(C=O)CO
# Nc1nc(N)c2nc(CCNc3ccc(C(=O)NC(CCC(O)=CS)C(=O)O)cc3)cnc2n1
# NCOC(=S)c1[nH]cnc1N
# CC(CC(C)(O)CCC(N)C(=O)O)NC(N)S
# C=C(N=C(N)S)C1CC1(C)O
# Nc1ccn(C2OC(OC=O)CC2=O)c(=O)n1
# NCNC(=S)c1[nH]cnc1N
# CC(=O)N=C(S)C(O)O
# CN(O)c1cccc(C(=O)NC(CCC(=O)O)C(=O)O)c1
# NC1=CC(=O)O1
# C=C1NOC1=O
# CC=C(C#N)C=C(COC(C)C)C(CO)NNC(C)=CC(C)(C)O
# C=C(CCC(C)O)N=C(S)C(=O)O
# C=C1C(N)=NC(=O)N1C1(O)C(=O)CC1OC=O
# CC(O)(C=CCN=C(N)I)CCC(NN)C(=O)O
# BC(N)O
# CC(CS)C(=O)O
# Nc1ccn(C2OC(CO)=C(O)C2O)c(=O)n1
# NNC1=COC2C(CC(N)=NC1=S)OC(n1ccc(N)nc1=O)C2O
# CO
# C=C(NC=N)C(=S)NC(N)C(=C)N=C(N)S
# CN(O)c1cccc(C(=O)BC(CCC(=O)O)C(=O)O)c1
# CS
# OC1C=CNO1
# N=C1NC(=S)C2N=C=NC2N1

# %%
fitness = get_fitness(last_population)
# Out:
# Extracted Data:      Lipinski        PPB   logVDss    CYP3A4-inh    CYP3A4-sub    CYP2D6-inh  \
# 0           0  18.358716 -0.194514  4.360477e-05  9.999652e-01  1.427963e-08
# 1           0  18.633429 -0.327651  1.270794e-14  2.732342e-19  8.033445e-13
# 2           0  34.083408  0.009093  3.886542e-06  5.218209e-06  1.133767e-03
# 3           0  21.182211 -0.288766  2.450746e-12  7.712645e-09  1.952026e-10
# 4           1  35.413930  0.046415  1.823592e-05  9.846741e-01  1.875105e-10
# ..        ...        ...       ...           ...           ...           ...
# 319         0  17.765641 -0.268550  2.649196e-08  2.879139e-05  9.696657e-09
# 320         0   5.892859  0.055438  2.564933e-04  8.186712e-02  2.187501e-01
 35),
#  (0, 31),
#  (0, 25),
#  (0, 24),
#  (0, 47),
#  (0, 17),
#  (0, 21),
#  (0, 40),
#  (0, 34),
#  (0, 4),
#  (0, 13),
#  (0, 12),
#  (0, 20),
#  (0, 19),
#  (0, 44),
#  (0, 37),
#  (0, 43),
#  (0, 28),
#  (0, 45),
#  (0, 30),
#  (0, 11),
#  (0, 35),
#  (0, 31),
#  (0, 25),
#  (0, 24),
#  (0, 47),
#  (0, 17),
#  (0, 21),
#  (0, 40),
#  (0, 34),
#  (0, 4),
#  (0, 13),
#  (0, 12),
#  (0, 20),
#  (0, 44),
#  (0, 37),
#  (0, 43),
#  (0, 28),
#  (0, 45),
#  (0, 30),
#  (0, 11),
#  (0, 35),
#  (0, 31),
#  (0, 25),
#  (0, 24),
#  (0, 47),
#  (0, 17),
#  (0, 21),
#  (0, 40),
#  (1, 34),
#  (0, 4),
#  (0, 13),
#  (0, 20),
#  (0, 44),
#  (0, 37),
#  (3, 43),
#  (0, 28),
#  (0, 45),
#  (0, 30),
#  (0, 11),
#  (0, 35),
#  (0, 31),
#  (0, 25),
#  (0, 24),
#  (2, 47),
#  (0, 17),
#  (0, 21),
#  (0, 40),
#  (0, 4),
#  (0, 20),
#  (0, 44),
#  (0, 37),
#  (0, 43),
#  (0, 28),
#  (0, 45),
#  (0, 30),
#  (0, 11),
#  (0, 35),
#  (0, 31),
#  (0, 25),
#  (0, 24),
#  (0, 47),
#  (0, 17),
#  (1, 21),
#  (0, 40),
#  (0, 4),
#  (0, 44),
#  (0, 37),
#  (0, 43),
#  (0, 28),
#  (8, 45),
#  (0, 30),
#  (0, 11),
#  (0, 35),
#  (0, 31),
#  (0, 25),
#  (0, 24),
#  (0, 47),
#  (0, 17),
#  (0, 21),
#  (0, 40),
#  (0, 44),
#  (0, 37),
#  (1, 43),
#  (0, 28),
#  (0, 45),
#  (6, 30),
#  (2, 11),
#  (2, 35),
#  (0, 31),
#  (0, 25),
#  (0, 24),
#  (0, 47),
#  (0, 17),
#  (0, 21),
#  (0, 40),
#  (2, 44),
#  (0, 37),
#  (0, 43),
#  (0, 28),
#  (0, 45),
#  (0, 30),
#  (0, 35),
#  (0, 31),
#  (0, 25),
#  (2, 24),
#  (1, 17),
#  (0, 21),
#  (0, 40),
#  (0, 44),
#  (0, 37),
#  (0, 43),
#  (0, 28),
#  (1, 45),
#  (3, 30),
#  (0, 35),
#  (0, 31),
#  (0, 25),
#  (0, 24),
#  (0, 17),
#  (0, 21),
#  (0, 40),
#  (0, 44),
#  (0, 37),
#  (0, 43),
#  (0, 28),
#  (0, 45),
#  (0, 30),
#  (0, 35),
#  (0, 31),
#  (0, 25),
#  (0, 24),
#  (0, 17),
#  (0, 21),
#  (0, 40),
#  (0, 44),
#  (0, 37),
#  (1, 43),
#  (0, 28),
#  (0, 45),
#  (0, 30),
#  (0, 35),
#  (0, 31),
#  (0, 25),
#  (0, 24),
#  (0, 17),
#  (0, 21),
#  (0, 44),
#  (0, 37),
#  (0, 43),
#  (0, 28),
#  (0, 45),
#  (0, 30),
#  (0, 35),
#  (0, 31),
#  (1, 25),
#  (0, 24),
#  (0, 17),
#  (0, 21),
#  (0, 44),
#  (0, 37)]

# %%
highest = []
highest_fitness = []
for index, score in enumerate(scores):
    if score[0] == 0:
        print(last_population[index], scores[index])
        highest.append(last_population[index])
        highest_fitness.append(fitness[index])

highest_fitness = dict(zip(highest, highest_fitness))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19412\1591171804.py in <module>
#       1 highest = []
#       2 highest_fitness = []
# ----> 3 for index, score in enumerate(scores):
#       4     if score[0] == 0:
#       5         print(last_population[index], scores[index])
#
# NameError: name 'scores' is not defined

# %%
Chem.Draw.MolsToGridImage([Chem.MolFromSmiles(mol) for mol in highest], molsPerRow=4, subImgSize=(200,200))
# Out:
# C:\Users\tubon\.conda\envs\chemo2\lib\site-packages\rdkit\Chem\Draw\IPythonConsole.py:261: UserWarning: Truncating the list of molecules to be displayed to 50. Change the maxMols value to display more.
#   warnings.warn(

# %%
# ['Lipinski', 'PPB', 'logVDss', 'CYP3A4-inh', 'CYP3A4-sub', 
# 'CYP2D6-inh', 'CYP2D6-sub', 'cl-plasma', 't0.5', 'DILI', 'hERG', 'Synth', 'Binding Affinity', 'HLG']

prop = 2

reversible = [0, 2, 4, 6, 8, 9, 11, 12]
is_reversed = not prop in reversible
highest_prop = sorted(highest, key=lambda x: highest_fitness[x][prop], reverse=is_reversed)

top_props = []

for prop in range(14):
    top_prop = []
    past_imp = 0

    reversible = [0, 2, 4, 6, 8, 9, 11, 12, 13]
    is_reversed = not prop in reversible
    highest_prop = sorted(highest, key=lambda x: highest_fitness[x][prop], reverse=is_reversed)

    for i in range(len(highest)):
        # print(highest_prop[i], highest_fitness[highest_prop[i]][prop])
        if highest_prop[i] in top_prop:
            continue
        top_prop.append(highest_prop[i])
        if highest_prop[i] in ["S=c1nc[nH]c2nc[nH]c12", "Nc1nc(=S)c2[nH]cnc2[nH]1"]:
            past_imp += 1

        if past_imp >= 2:
            break
    top_props += top_prop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19412\2507357202.py in <module>
#       6 reversible = [0, 2, 4, 6, 8, 9, 11, 12]
#       7 is_reversed = not prop in reversible
# ----> 8 highest_prop = sorted(highest, key=lambda x: highest_fitness[x][prop], reverse=is_reversed)
#       9
#      10 top_props = []
#
# NameError: name 'highest' is not defined

# %%
from collections import Counter
print(Counter(top_props))
# Out:
# Counter({'Nc1c#cn(C2OC(OC=O)CC2=O)c(=O)n1': 13, 'Nc1nc(=S)c2[nH]cnc2[nH]1': 13, 'S=c1nc[nH]c2nc[nH]c12': 13, 'NC(O)O': 12, 'C=C(N)C=COCCCN': 12, 'S=c1nc2[nH]c3nc([nH]c13)N2': 12, 'Nc1nc(=O)n2cc1N(C(CCC(=O)O)C(=O)O)C(=O)C(NNC(CCC(=O)O)C(=O)O)=COC1CC(=O)C2O1': 12, 'C=C(CCC(C)O)N=C(N)S': 12, 'NC=BC(=O)O': 12, 'C=C1C(N)=NC(=O)N1C1(O)C(=O)CC1OO': 12, 'CC(=NC=C(N)NN)N=C(N)N=CN': 12, 'N=CNC=CNN': 12, 'N=Cn1[nH]c2nc[nH]c2c1=S': 12, 'CS': 11, 'C=C(N=C(N)S)C1CC1(C)O': 11, 'BCNO': 11, 'CC(=CC=CCC(=O)NC(NC=N)C(=O)O)CNNC(C=N)=C(N)Cl': 11, 'CC(=O)N=C(N)S': 11, 'CC(=O)N=CNBr': 11, 'N=CS': 11, 'CC(=CC(C)(O)CCC(NN)C(=O)O)N=C(N)S': 11, 'O=C1CO1': 11, 'NC1NC(=S)c2[nH]cnc2N1': 11, 'C=C(N)C=CC(O)CC(C)(O)C=C(C)N=C(N)S': 11, 'NCC(O)CO': 11, 'Nc1ccn(C2OC(CO)C(O)C2O)c(=O)n1': 11, 'CONC(C)=O': 11, 'CC(=NC(N)=CCN(N)CCN)N=C(N)N=CN': 11, 'C=C(N)N=C(NC)C(=O)O': 11, 'COC(C=O)OC(CO)N(C=O)C=CC(=N)CC(NC(=O)c1cccc(CNNc2cnc3nc(N)nc(N)c3n2)c1)C(=O)O': 11, 'NO': 10, 'N=c1[nH]c2c(c(=S)[nH]1)N=C=N2': 10, 'CNC1(N)C=C(N)N1': 10, 'C=C1CCC(O)CNNC(C(=O)NC(CCC(=O)O)C(=O)O)=CC(C)=CC(S)=N1': 10, 'Nc1c(=S)ncn2[nH]cnc12': 10, 'N': 10, 'N=Cn1[nH]c2c(c1=S)NCN2': 10, 'C=C(N)C1=CN1': 10, 'C=C(NC=N)C(S)NC(N)N': 10, 'CC1(O)C=C(N=C(N)S)CC1': 10, 'N=S': 10, 'C=C(CCC(C)O)N=C(C)NNCC(C)=CC=CCC(=O)NC(CCC(C)(O)C=C(C)N=C(N)S)C(=O)O': 10, 'Cc1c(=S)ncn2[nH]cnc12': 10, 'CC(=CC=C(Cl)CCl)CN': 10, 'N=C=CC(=O)O': 10, '
(=S)N(CN)C(=C)NC=N': 9, 'O=C1C=C=NO1': 9, 'Nc1ccn(C2OC(OCCC(=O)O)CC2=O)c(=O)n1': 9, 'C=C(N)N=C(N)C=N': 9, 'NN': 9, 'CC(=O)N=CNS': 9, 'CC(=O)N=C(Cl)Br': 9, 'NNC1=COC2C(CC(N)=NC1=S)OC(n1ccc(N)nc1=O)C2O': 9, 'Nc1ccn(C2OC(CC(=O)O)C(O)C2O)c(=O)n1': 9, 'O=C1c2cn1o2': 9, 'CC(=O)N=CSN': 9, 'NC(CCC(=O)O)C(=O)O': 9, 'CC(=NC(=CN)NN)N=C(N)N=CN': 9, 'CC(N)=CC=CCCNNC(N)=CN=C(C)N=C(N)N=CN': 9, 'CC(=CC=C(C)N(C)CC(N)=CN=C(C)N=C(N)N=CN)C(=O)CC1OC(n2ccc(N)nc2=O)C(O)C1O': 8, 'N=CNN': 8, 'CC(O)(C=CCN=C(N)I)CCC(N=N)C(=O)O': 8, 'C=C(CCC(C)O)N=C(S)C(C)=CC=C(NN)C(=O)NC(CCC(=O)C(=N)C=CN(C=O)C(CO)OC(C)(O)C=O)C(=O)O': 8, 'CC(C(=O)O)C(NO)C(=O)O': 8, 'C=C1CCC(O)CC(CCC(=O)O)(C(=O)O)NC(=O)C(C)=CC=C(C)C(S)=N1': 8, 'S=c1nc2[nH]c3nn2cc1N3': 8, 'NC(N)S': 8, 'CC(=CC=CCC(=O)NC(NC=N)C(=O)O)CNNC(C=N)=NC(C)=C(N)N=C(N)C(C)CCC(C)O': 8, 'NN(O)O': 8, 'S=C1N=CNNc2nc[nH]c21': 8, 'OCCO': 8, 'C=C(NC=N)C(=S)NO': 8, 'CN(Nc1cncnc(N)nc(N)cn1)c1cccc(C(=O)NC(CCC(=O)O)C(=O)O)c1': 8, 'CC(O)=CC(C)(O)CCC(NN)C( ...

# %%
# Lipinski
# PPB
# logVDss
# CYP3A4-inh
# CYP3A4-sub
# CYP2D6-inh
# CYP2D6-sub
# cl-plasma
# t0.5
# DILI
# hERG
# Synthesizability
# Binding Affinity

# %%
interesting = ["S=c1nc[nH]c2nc[nH]c12",
               "Nc1nc(=S)c2[nH]cnc2[nH]1",
               "Nc1c#cn(C2OC(OC=O)CC2=O)c(=O)n1",
               "S=c1nc2[nH]c3nc([nH]c13)N2",
               "C=C(CCC(C)O)N=C(N)S",
               "C=C1C(N)=NC(=O)N1C1(O)C(=O)CC1OO",
               "CC(=NC=C(N)NN)N=C(N)N=CN",
               "N=Cn1[nH]c2nc[nH]c2c1=S",
               "NC1NC(=S)c2[nH]cnc2N1",
               "Cc1c(=S)ncn2[nH]cnc12"]

# %%
Chem.Draw.MolsToGridImage([Chem.MolFromSmiles(mol) for mol in interesting], molsPerRow=4, subImgSize=(500,500))

# %%
for mol in interesting:
    labels = ["Lipinski", "PPB", "logVDss", "CYP3A4-inh", "CYP3A4-sub", "CYP2D6-inh", "CYP2D6-sub", "cl-plasma", "t0.5", "DILI", "hERG", "Synthesizability", "Binding Affinity", "HLG"]
    print(mol)
    for i in range(len(labels)):
        print(f"{labels[i]}:", highest_fitness[mol][i])
    print()
# Out:
# S=c1nc[nH]c2nc[nH]c12
# Lipinski: 0.0
# PPB: 22.449265736133967
# logVDss: 0.0801635087566263
# CYP3A4-inh: 9.547449735691773e-06
# CYP3A4-sub: 1.0792386092361994e-05
# CYP2D6-inh: 0.000210722660995
# CYP2D6-sub: 0.678745448589325
# cl-plasma: 5.172707624964405
# t0.5: 1.157960300752891
# DILI: 0.6229879856109619
# hERG: 0.0587557628750801
# Synthesizability: 5.286
# Binding Affinity: 2004.308470436545
#
# Nc1nc(=S)c2[nH]cnc2[nH]1
# Lipinski: 0.0
# PPB: 16.24584382005368
# logVDss: -0.0802783987983008
# CYP3A4-inh: 0.0144703919067978
# CYP3A4-sub: 0.0764553174376487
# CYP2D6-inh: 0.0012864493764936
# CYP2D6-sub: 0.0006764131248928
# cl-plasma: 2.0035730772979083
# t0.5: 2.284688662650132
# DILI: 0.7274777293205261
# hERG: 0.0620070248842239
# Synthesizability: 4.745
# Binding Affinity: 2264.6524551329194
#
# Nc1c#cn(C2OC(OC=O)CC2=O)c(=O)n1
# Lipinski: 0.0
# PPB: 56.56676617739125
# logVDss: 0.0116047591451612
# CYP3A4-inh: 0.1620569378137588
# CYP3A4-sub: 0.0617289878427982
# CYP2D6-inh: 0.0077502033673226
# CYP2D6-sub: 0.1923656463623047
# cl-plasma: 6.013257897749723
# t0.5: 1.6994975410641808
# DILI: 0.1227720454335212
# hERG: 0.0621248707175254
# Synthesizability: 4.084
# Binding Affinity: 36.18788169847585
#
# S=c1nc2[nH]c3nc([nH]c13)N2
# Lipinski: 0.0
# PPB: 22.97983866574901
# logVDss: -0.1297992702392132
# CYP3A4-inh: 0.0002507018216419
# CYP3A4-sub: 0.0004066888359375
# CYP2D6-inh: 4.5792955916112987e-07
# CYP2D6-sub: 2.2571450699615525e-06
# cl-plasma: 4.395392524544666
# t0.5: 1.2547987989972698
# DILI: 0.0005046297446824
# hERG: 0.0661886781454086
# Synthesizability: 4.628
# Binding Affinity: 1722.449694801621
#
# C=C(CCC(C)O)N=C(N)S
# Lipinski: 0.0
# PPB: 20.153086040328887
# logVDss: -0.2722467024841369
# CYP3A4-inh: 6.158566975500435e-05
# CYP3A4-sub: 0.0004368081572465
# CYP2D6-inh: 1.5017329602073914e-08
# CYP2D6-sub: 0.0001874873560154
# cl-plasma: 3.1347343529957805
# t0.5: 1.9097665541781477
# DILI: 0.045646134763956
# hERG: 0.1128183081746101
# Synthesizability: 5.068
# Binding Affinity: 399.19487893171083
#
# C=C1C(N)=NC(=O)N1C1(O)C(=O)CC1OO
# Lipinski: 0.0
# PPB: 21.22694861464577
# logVDss: -0.1589996515632411
# CYP3A4-inh: 0.0001401187764713
# CYP3A4-sub: 0.0046348674222826
# CYP2D6-inh: 1.0597621979968609e-07
# CYP2D6-sub: 1.686920950305648e-05
# cl-plasma: 6.417510169386304
# t0.5: 1.4157909495495704
# DILI: 0.0079512987285852
# hERG: 0.065603069961071
# Synthesizability: 4.309
# Binding Affinity: -533.6618280484598
#
# CC(=NC=C(N)NN)N=C(N)N=CN
# Lipinski: 0.0
# PPB: 15.377651060317383
# logVDss: -0.0288897149516946
# CYP3A4-inh: 0.0015952286776155
# CYP3A4-sub: 0.0005535267991945
# CYP2D6-inh: 0.0044209021143615
# CYP2D6-sub: 0.3045187890529632
# cl-plasma: 7.323278917828221
# t0.5: 1.4683314513232015
# DILI: 0.609088122844696
# hERG: 0.0738725662231445
# Synthesizability: 4.32
# Binding Affinity: 499.8224828068236
#
# N=Cn1[nH]c2nc[nH]c2c1=S
# Lipinski: 0.0
# PPB: 1.4837210668881085
# logVDss: -0.0949820707390839
# CYP3A4-inh: 0.0432495139539241
# CYP3A4-sub: 0.0170303042978048
# CYP2D6-inh: 0.000635792617686
# CYP2D6-sub: 0.0802529454231262
# cl-plasma: 7.706422725900819
# t0.5: 0.9396822912922618
# DILI: 0.4866628050804138
# hERG: 0.1472464054822921
# Synthesizability: 4.482
# Binding Affinity: 1818.1391691118783
#
# NC1NC(=S)c2[nH]cnc2N1
# Lipinski: 0.0
# PPB: 10.50470136367788
# logVDss: 0.0428452431979663
# CYP3A4-inh: 0.0001444657973479
# CYP3A4-sub: 0.0001403261558152
# CYP2D6-inh: 0.0023607553448528
# CYP2D6-sub: 0.1294417977333068
# cl-plasma: 2.097520127843343
# t0.5: 1.8204325870406772
# DILI: 0.7699629068374634
# hERG: 0.1315912157297134
# Synthesizability: 4.614
# Binding Affinity: 774.5960386449801
#
# Cc1c(=S)ncn2[nH]cnc12
# Lipinski: 0.0
# PPB: 20.7987064346024
# logVDss: -0.2697359987828882
# CYP3A4-inh: 8.614800428574654e-09
# CYP3A4-sub: 2.3385005931686464e-08
# CYP2D6-inh: 4.339676706877072e-08
# CYP2D6-sub: 0.2168905287981033
# cl-plasma: 5.3534340187651726
# t0.5: 1.2557131194137097
# DILI: 0.0558571219444274
# hERG: 0.0235150046646595
# Synthesizability: 5.017
# Binding Affinity: -281.3071503495056

# %% [markdown]
# ## Visualize property evolution

# %%
import matplotlib.pyplot as plt

# %%
iterations = list(range(len(history)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3792\1696759006.py in <module>
# ----> 1 iterations = list(range(len(history)))
#
# NameError: name 'history' is not defined

# %%
labels = ["Lipinski", "PPB", "logVDss", "CYP3A4-inh", "CYP3A4-sub", "CYP2D6-inh", "CYP2D6-sub", "cl-plasma", "t0.5", "DILI", "hERG", "Synthesizability", "Binding Affinity", "HLG"]

average_fitness_scores_per_gen = []
for i in range(len(labels)):
    generational_average = []
    for pop in len(history):
        total = 0
        for score in history[pop]["scores"]:
            total += score[i]

        generational_averages.append(total/len(highest_fitness))    

    average_fitness_scores_per_gen.append(generational_averages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19412\1686322044.py in <module>
#       2
#       3 average_fitness_scores = []
# ----> 4 for _ in len(history):
#       5     average_prop = []
#       6     for i in range(len(labels)):
#
# NameError: name 'history' is not defined

# %%
for prop in range(len(labels)):
    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.plot(iterations, objective_scores, label="Objective Score", color="blue", linewidth=2)
    plt.title("Optimization Progress", fontsize=16)
    plt.xlabel("Iteration", fontsize=14)
    plt.ylabel("Objective Score", fontsize=14)
    plt.grid(True, which="both", linestyle="--", linewidth=0.5)
    plt.legend(fontsize=12)
    plt.tight_layout()

    # Show the plot
    plt.show()
